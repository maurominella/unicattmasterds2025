# %%
if (10 > 5) == 1:
    print("Ten is greater than five")
# Out:
# Ten is greater than five

# %%
def sum (a:int, b:float):
    """
    This function calculates
    the sum of two numbers
    """
    result = a+b # calculate the result
    return result # return the result

# %%
sum(

# %%
sum(4,6)
# Out:
# 10

# %%
age = 30.7

# %%
age = "thirty"

# %%
type(age)
# Out:
# float

# %%
type(10 > 5)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %%
fistName = "John"
FirstName = "Elisa"
firstdayoftheyear

# %%
f = 3.999
int(f)
# Out:
# 3

# %%
i= 100
type(float(i))
# Out:
# float

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %%
maxDistance:int =  "hello!"

# %%
type(maxDistance)
# Out:
# str

# %%
float(str(99.99))
# Out:
# 99.99

# %%
2**10
# Out:
# 1024

# %%
20 // 6
# Out:
# 3

# %% [markdown]
# # First paragraph
# ## Second paragraph
# Bullet points
# - one
# - two
# - three
#
# [Link](https://www.bing.com)
#
# # Screenshot:
# ![image.png](attachment:358292ac-eb30-417c-855c-ffae148e5f45.png)

# %%
a = 10
b = 5

# %%
n = a + b
n
# Out:
# 15

# %%
n == a + b
# Out:
# True

# %%
a += 5
a
# Out:
# 15

# %%
3 == 3.0
# Out:
# True

# %%
"hello" == "hello"
# Out:
# True

# %%
x = input("Enter x:")
y = input("Enter y:")
z = str(int(x)+int(y))

print("The sum is " + z)
# Out:
# Enter x: 100
# Enter y: 50
# The sum is 150

# %%
print("IS a*b == 50", a*b==50, 1,2,3, sep="\n")
# Out:
# IS a*b == 50
# True
# 1
# 2
# 3

# %%
print (
'''
My wife said "NO!"
While my daugther said "YES"
'''
)
# Out:
# My wife said "NO!"
# While my daugther said "YES"

# %%
s = "Today we have a strike in Milan"
s[3:10] # just the chars from 3 to 10 or the string
s[:10] # the first 10 chars of the string
s[10:] # the string, starting from the 10th char
s[:-10] # the whole string "except" the last 10 chars
s[-10:] # the last 10 chars of the string
# Out:
# 'e in Milan'

# %%
print("the sum of {}".format(a))
# Out:
# the sum of 10

# %%
print(f"the sum of {a} and {b} is {a+b}")
# Out:
# the sum of 10 and 5 is 15
